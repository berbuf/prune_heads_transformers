# %%
from matplotlib.pyplot import bar
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
def round_gates(gates):
    gates[gates < 0.5] = 0
    gates[gates > 0.5] = 1
    return gates

def gen_token():
    with open("./res_lower.json") as f:
        text = [ json.loads(l) for l in f.readlines() ]
    for l in text:
        line = " ".join(l["text"])
        for t in l["tokens"]:
            yield t["token"], t["pos"], t["dep"], t["gates"], line

# %% [markdown]
# # inner variance

# %%
nouns = [ (token, pos, dep, gates, line) for token, pos, dep, gates, line in gen_token() if pos == "NOUN" ]

# %%
nouns = sorted(nouns, key=lambda x: len(x[4]))

# %%
bold = lambda x: '\x1b[1;31m' + x + '\x1b[0m'
for token, pos, dep, gates, line in nouns:
    print (" ".join([bold(l) if l == token else l  for l in line.split(" ")]))
    print (dep, round(sum(gates)), sum(round_gates(np.array(gates).copy())), len(line))
    print ()
# Out:
# [CLS] that is one of the reasons i am here . [SEP]
# pobj 12 9.0 50
#
# [CLS] all four tasmanian boats have finished . [SEP]
# nsubj 22 13.0 52
#
# [CLS] i am for dialogue and i keep on saying this [SEP]
# pobj 54 28.0 55
#
# [CLS] india ruled out any face - to - face talks . [SEP]
# nmod 9 9.0 56
#
# [CLS] india ruled out any face - to - face talks . [SEP]
# pobj 11 9.0 56
#
# [CLS] india ruled out any face - to - face talks . [SEP]
# dobj 37 22.0 56
#
# [CLS] the were no reported injuries onboard . [UNK] [SEP]
# attr 14 9.0 57
#
# [CLS] nicky [UNK] might be out in time , " he said . [SEP]
# pobj 21 13.0 58
#
# [CLS] the others fell victim to the [UNK] conditions . [SEP]
# nsubj 19 12.0 60
#
# [CLS] the others fell victim to the [UNK] conditions . [SEP]
# dobj 30 18.0 60
#
# [CLS] the others fell victim to the [UNK] conditions . [SEP]
# pobj 19 13.0 60
#
# [CLS] i will be in shape by the end of the tournament . [SEP]
# pobj 19 11.0 61
#
# [CLS] i will be in shape by the end of the tournament . [SEP]
# pobj 16 8.0 61
#
# [CLS] i will be in shape by the end of the tournament . [SEP]
# pobj 32 20.0 61
#
# [CLS] but i want to try not to peak too early this season . [SEP]
# npadvmod 20 13.0 65
#
# [CLS] let the two countries move towards peace and harmony . [SEP]
# nsubj 20 15.0 66
#
# [CLS] let the two countries move towards peace and harmony . [SEP]
# pobj 15 12.0 66
#
# [CLS] let the two countries move towards peace and harmony . [SEP]
# conj 14 11.0 66
#
# [CLS] the event raised about $ [UNK] for the red cross . [UNK] [SEP]
# nsubj 37 24.0 68
#
# [CLS] the nine metre yacht is among 16 boats still to finish . [SEP]
# compound 31 21.0 68
#
# [CLS] the nine metre yacht is among 16 boats still to finish . [SEP]
# nsubj 17 12.0 68
#
# [CLS] the nine metre yacht is among 16 boats still to finish . [SEP]
# pobj 19 16.0 68
#
# [CLS] zeus two is still eight hours away from the finish line . [SEP]
# npadvmod 13 9.0 69
#
# [CLS] zeus two is still eight hours away from the finish line . [SEP]
# compound 20 15.0 69
#
# [CLS] zeus two is still eight hours away from the finish line . [SEP]
# pobj 27 17.0 69
#
# [CLS] [UNK] said the win was a great way to start the tennis year . [SEP]
# nsubj 19 11.0 73
#
# [CLS] [UNK] said the win was a great way to start the tennis year . [SEP]
# attr 7 5.0 73
#
# [CLS] [UNK] said the win was a great way to start the tennis year . [SEP]
# compound 41 23.0 73
#
# [CLS] [UNK] said the win was a great way to start the tennis year . [SEP]
# dobj 9 6.0 73
#
# [CLS] [UNK] said she had expected her clash with [UNK] to be tough . [SEP]
# nsubj 36 26.0 74
#
# [CLS] there is already the agreement , so it was [UNK] , " he said . [SEP]
# attr 24 15.0 74
#
# [CLS] they were killed by shell fire from a tank , the sources said . [SEP]
# compound 26 17.0 75
#
# [CLS] they were killed by shell fire from a tank , the sources said . [SEP]
# pobj 11 11.0 75
#
# [CLS] they were killed by shell fire from a tank , the sources said . [SEP]
# pobj 31 18.0 75
#
# [CLS] they were killed by shell fire from a tank , the sources said . [SEP]
# nsubj 26 16.0 75
#
# [CLS] greater sydney is [UNK] by fires to the north , west and south . [SEP]
# pobj 42 27.0 76
#
# [CLS] greater sydney is [UNK] by fires to the north , west and south . [SEP]
# pobj 13 12.0 76
#
# [CLS] greater sydney is [UNK] by fires to the north , west and south . [SEP]
# conj 15 13.0 76
#
# [CLS] greater sydney is [UNK] by fires to the north , west and south . [SEP]
# conj 14 11.0 76
#
# [CLS] an estimated 500 residents have left their homes for nearby [UNK] . [SEP]
# nsubj 13 9.0 79
#
# [CLS] an estimated 500 residents have left their homes for nearby [UNK] . [SEP]
# dobj 14 11.0 79
#
# [CLS] , both won their singles encounters to give the us an [UNK] 2 - 0 lead . [SEP]
# dobj 22 16.0 84
#
# [CLS] , both won their singles encounters to give the us an [UNK] 2 - 0 lead . [SEP]
# dobj 31 19.0 84
#
# [CLS] , both won their singles encounters to give the us an [UNK] 2 - 0 lead . [SEP]
# dobj 25 18.0 84
#
# [CLS] one at [UNK] in the southern highlands was quickly brought under control . [SEP]
# pobj 53 28.0 86
#
# [CLS] one at [UNK] in the southern highlands was quickly brought under control . [SEP]
# pobj 40 22.0 86
#
# [CLS] the lack of a suitable translation of the document meant a further delay . [SEP]
# nsubj 7 5.0 86
#
# [CLS] the lack of a suitable translation of the document meant a further delay . [SEP]
# pobj 22 14.0 86
#
# [CLS] the lack of a suitable translation of the document meant a further delay . [SEP]
# pobj 29 19.0 86
#
# [CLS] the lack of a suitable translation of the document meant a further delay . [SEP]
# dobj 21 15.0 86
#
# [CLS] a spokesman says a decision regarding their future is yet to be made . [UNK] [SEP]
# nsubj 37 21.0 88
#
# [CLS] a spokesman says a decision regarding their future is yet to be made . [UNK] [SEP]
# nsubj 17 12.0 88
#
# [CLS] a spokesman says a decision regarding their future is yet to be made . [UNK] [SEP]
# pobj 25 17.0 88
#
# [CLS] the pair , runners - up in the $ 1 million dollar mixed teams event last year [SEP]
# nmod 42 29.0 89
#
# [CLS] the pair , runners - up in the $ 1 million dollar mixed teams event last year [SEP]
# compound 11 10.0 89
#
# [CLS] the pair , runners - up in the $ 1 million dollar mixed teams event last year [SEP]
# ROOT 8 6.0 89
#
# [CLS] the pair , runners - up in the $ 1 million dollar mixed teams event last year [SEP]
# nmod 16 10.0 89
#
# [CLS] the pair , runners - up in the $ 1 million dollar mixed teams event last year [SEP]
# compound 30 20.0 89
#
# [CLS] the pair , runners - up in the $ 1 million dollar mixed teams event last year [SEP]
# pobj 17 14.0 89
#
# [CLS] the pair , runners - up in the $ 1 million dollar mixed teams event last year [SEP]
# npadvmod 45 26.0 89
#
# [CLS] [UNK] was pressed hard by clement before taking the first set in 47 minutes . [SEP]
# dobj 29 19.0 89
#
# [CLS] [UNK] was pressed hard by clement before taking the first set in 47 minutes . [SEP]
# pobj 30 16.0 89
#
# [CLS] some roads are closed because of dangerous conditions caused by [UNK] smoke . [SEP]
# nsubjpass 12 9.0 89
#
# [CLS] some roads are closed because of dangerous conditions caused by [UNK] smoke . [SEP]
# pobj 15 13.0 89
#
# [CLS] some roads are closed because of dangerous conditions caused by [UNK] smoke . [SEP]
# pobj 37 19.0 89
#
# [CLS] the president said he had received the " support of all political parties " . [SEP]
# dobj 12 8.0 89
#
# [CLS] the president said he had received the " support of all political parties " . [SEP]
# pobj 15 11.0 89
#
# [CLS] but he says the major threat to most people seeking asylum is no longer there . [SEP]
# nsubj 16 12.0 91
#
# [CLS] but he says the major threat to most people seeking asylum is no longer there . [SEP]
# pobj 16 12.0 91
#
# [CLS] but he says the major threat to most people seeking asylum is no longer there . [SEP]
# dobj 42 28.0 91
#
# [CLS] we would like anybody to play a useful and positive role in [UNK] the tension . [SEP]
# nsubj 43 23.0 91
#
# [CLS] we would like anybody to play a useful and positive role in [UNK] the tension . [SEP]
# dobj 9 6.0 91
#
# [CLS] we would like anybody to play a useful and positive role in [UNK] the tension . [SEP]
# dobj 36 18.0 91
#
# [CLS] and india keeps on rejecting which gives me a feeling that i am begging to india . [SEP]
# dobj 19 14.0 94
#
# [CLS] well , the taliban is no longer in power in afghanistan , the taliban is finished . [SEP]
# pobj 18 12.0 95
#
# [CLS] gale force winds [UNK] trees and brought down power lines , damaging homes and cars . [SEP]
# compound 14 7.0 97
#
# [CLS] gale force winds [UNK] trees and brought down power lines , damaging homes and cars . [SEP]
# compound 24 13.0 97
#
# [CLS] gale force winds [UNK] trees and brought down power lines , damaging homes and cars . [SEP]
# nsubj 25 22.0 97
#
# [CLS] gale force winds [UNK] trees and brought down power lines , damaging homes and cars . [SEP]
# dobj 27 18.0 97
#
# [CLS] gale force winds [UNK] trees and brought down power lines , damaging homes and cars . [SEP]
# compound 19 16.0 97
#
# [CLS] gale force winds [UNK] trees and brought down power lines , damaging homes and cars . [SEP]
# dobj 24 17.0 97
#
# [CLS] gale force winds [UNK] trees and brought down power lines , damaging homes and cars . [SEP]
# conj 18 13.0 97
#
# [CLS] gale force winds [UNK] trees and brought down power lines , damaging homes and cars . [SEP]
# conj 23 15.0 97
#
# [CLS] spain has begun its [UNK] cup campaign in perth with a 3 - 0 victory over argentina . [SEP]
# dobj 12 8.0 97
#
# [CLS] spain has begun its [UNK] cup campaign in perth with a 3 - 0 victory over argentina . [SEP]
# pobj 11 8.0 97
#
# [CLS] marks sullivan from the rural fire service says fire fighters are remaining on guard . [SEP]
# compound 9 6.0 98
#
# [CLS] marks sullivan from the rural fire service says fire fighters are remaining on guard . [SEP]
# nsubj 38 27.0 98
#
# [CLS] marks sullivan from the rural fire service says fire fighters are remaining on guard . [SEP]
# pobj 24 18.0 98
#
# [CLS] hospitals have urged the public to donate medicine for the hundreds of burns victims . [SEP]
# nsubj 16 12.0 98
#
# [CLS] hospitals have urged the public to donate medicine for the hundreds of burns victims . [SEP]
# dobj 28 18.0 98
#
# [CLS] hospitals have urged the public to donate medicine for the hundreds of burns victims . [SEP]
# dobj 27 19.0 98
#
# [CLS] hospitals have urged the public to donate medicine for the hundreds of burns victims . [SEP]
# pobj 9 6.0 98
#
# [CLS] hospitals have urged the public to donate medicine for the hundreds of burns victims . [SEP]
# compound 42 19.0 98
#
# [CLS] hospitals have urged the public to donate medicine for the hundreds of burns victims . [SEP]
# pobj 13 9.0 98
#
# [CLS] i got a little tentative at the end , but it was a great start to my year , " he said . [SEP]
# pobj 23 14.0 99
#
# [CLS] i got a little tentative at the end , but it was a great start to my year , " he said . [SEP]
# attr 16 13.0 99
#
# [CLS] i got a little tentative at the end , but it was a great start to my year , " he said . [SEP]
# pobj 34 25.0 99
#
# [CLS] two fires burning near [UNK] , west of newcastle , are still within containment lines . [SEP]
# nsubj 15 11.0 99
#
# [CLS] two fires burning near [UNK] , west of newcastle , are still within containment lines . [SEP]
# appos 14 10.0 99
#
# [CLS] two fires burning near [UNK] , west of newcastle , are still within containment lines . [SEP]
# compound 30 21.0 99
#
# [CLS] two fires burning near [UNK] , west of newcastle , are still within containment lines . [SEP]
# pobj 27 15.0 99
#
# [CLS] [UNK] had to fight hard to get home in straight sets , winning 6 - 3 , 6 - 4 in 62 minutes . [SEP]
# pobj 17 12.0 104
#
# [CLS] [UNK] had to fight hard to get home in straight sets , winning 6 - 3 , 6 - 4 in 62 minutes . [SEP]
# pobj 14 11.0 104
#
# [CLS] rain has fallen in some parts of the [UNK] , sydney , the hunter valley and the north coast . [SEP]
# nsubj 22 19.0 105
#
# [CLS] rain has fallen in some parts of the [UNK] , sydney , the hunter valley and the north coast . [SEP]
# pobj 36 28.0 105
#
# [CLS] rain has fallen in some parts of the [UNK] , sydney , the hunter valley and the north coast . [SEP]
# compound 13 9.0 105
#
# [CLS] rain has fallen in some parts of the [UNK] , sydney , the hunter valley and the north coast . [SEP]
# conj 22 20.0 105
#
# [CLS] yesterday , pakistan announced it had arrested [UNK] - e - [UNK] chief [UNK] mohammed [UNK] . [SEP]
# npadvmod 14 8.0 105
#
# [CLS] yesterday , pakistan announced it had arrested [UNK] - e - [UNK] chief [UNK] mohammed [UNK] . [SEP]
# compound 33 19.0 105
#
# [CLS] but the american gained the [UNK] in the second set , breaking in the third and fifth games . [SEP]
# pobj 23 15.0 105
#
# pobj 12 9.0 110
#
# [CLS] meanwhile , a new fire in sydney [UNK] west is no longer threatening properties in the [UNK] area . [SEP]
# nsubj 13 11.0 111
#
# [CLS] meanwhile , a new fire in sydney [UNK] west is no longer threatening properties in the [UNK] area . [SEP]
# pobj 17 11.0 111
#
# [CLS] meanwhile , a new fire in sydney [UNK] west is no longer threatening properties in the [UNK] area . [SEP]
# dobj 39 19.0 111
#
# [CLS] meanwhile , a new fire in sydney [UNK] west is no longer threatening properties in the [UNK] area . [SEP]
# pobj 17 14.0 111
#
# [CLS] peru [UNK] president alejandro toledo has cut short his beach holiday to oversee an inquiry . [UNK] [SEP]
# compound 29 17.0 111
#
# [CLS] peru [UNK] president alejandro toledo has cut short his beach holiday to oversee an inquiry . [UNK] [SEP]
# dobj 25 14.0 111
#
# [CLS] peru [UNK] president alejandro toledo has cut short his beach holiday to oversee an inquiry . [UNK] [SEP]
# dobj 33 20.0 111
#
# [CLS] the shootout took place at dora village some 50 kilometers south of the [UNK] summer capital [UNK] . [SEP]
# nsubj 38 24.0 112
#
# [CLS] the shootout took place at dora village some 50 kilometers south of the [UNK] summer capital [UNK] . [SEP]
# dobj 35 23.0 112
#
# [CLS] the shootout took place at dora village some 50 kilometers south of the [UNK] summer capital [UNK] . [SEP]
# pobj 32 23.0 112
#
# [CLS] the shootout took place at dora village some 50 kilometers south of the [UNK] summer capital [UNK] . [SEP]
# npadvmod 16 12.0 112
#
# [CLS] the shootout took place at dora village some 50 kilometers south of the [UNK] summer capital [UNK] . [SEP]
# compound 18 13.0 112
#
# [CLS] the shootout took place at dora village some 50 kilometers south of the [UNK] summer capital [UNK] . [SEP]
# compound 36 28.0 112
#
# [CLS] [UNK] is a great [UNK] and i am delighted to beat him , even though i am frankly a bit out of shape . [SEP]
# npadvmod 14 9.0 113
#
# [CLS] [UNK] is a great [UNK] and i am delighted to beat him , even though i am frankly a bit out of shape . [SEP]
# pobj 31 21.0 113
#
# [CLS] 20 people have died on new south wales roads , with eight fatalities in both queensland and victoria . [SEP]
# nsubj 18 11.0 114
#
# [CLS] 20 people have died on new south wales roads , with eight fatalities in both queensland and victoria . [SEP]
# pobj 25 18.0 114
#
# [CLS] 20 people have died on new south wales roads , with eight fatalities in both queensland and victoria . [SEP]
# pobj 22 19.0 114
#
# [CLS] the government has suspended their applications while the interim government is established in kabul . [SEP]
# dobj 39 23.0 114
#
# [CLS] the government has suspended their applications while the interim government is established in kabul . [SEP]
# nsubjpass 14 8.0 114
#
# [CLS] [UNK] was forced to withdraw from the south african squad before the start of the tour due to injury . [SEP]
# pobj 23 16.0 114
#
# [CLS] [UNK] was forced to withdraw from the south african squad before the start of the tour due to injury . [SEP]
# pobj 15 11.0 114
#
# [CLS] [UNK] was forced to withdraw from the south african squad before the start of the tour due to injury . [SEP]
# pobj 25 19.0 114
#
# [CLS] [UNK] was forced to withdraw from the south african squad before the start of the tour due to injury . [SEP]
# pobj 16 11.0 114
#
# [CLS] she was a top junior player in the world , so it was no surprise that she fought so well , " she said . [SEP]
# attr 10 10.0 115
#
# [CLS] she was a top junior player in the world , so it was no surprise that she fought so well , " she said . [SEP]
# pobj 19 15.0 115
#
# [CLS] she was a top junior player in the world , so it was no surprise that she fought so well , " she said . [SEP]
# attr 40 23.0 115
#
# [CLS] but fire authorities are not getting overly optimistic as dry and hot weather is forecast to continue . [SEP]
# compound 29 19.0 115
#
# [CLS] but fire authorities are not getting overly optimistic as dry and hot weather is forecast to continue . [SEP]
# nsubj 25 17.0 115
#
# [CLS] but fire authorities are not getting overly optimistic as dry and hot weather is forecast to continue . [SEP]
# nsubjpass 13 10.0 115
#
# [CLS] india [UNK] pakistan [UNK] military intelligence of [UNK] the assault , but pakistan denies the [UNK] . [SEP]
# dobj 33 23.0 115
#
# [CLS] india [UNK] pakistan [UNK] military intelligence of [UNK] the assault , but pakistan denies the [UNK] . [SEP]
# dobj 40 25.0 115
#
# [CLS] and that [UNK] why we [UNK] take the action of [UNK] them and we [UNK] consider further action next week . [SEP]
# dobj 16 12.0 118
#
# [CLS] and that [UNK] why we [UNK] take the action of [UNK] them and we [UNK] consider further action next week . [SEP]
# dobj 18 13.0 118
#
# [CLS] and that [UNK] why we [UNK] take the action of [UNK] them and we [UNK] consider further action next week . [SEP]
# npadvmod 31 19.0 118
#
# [CLS] during the fire fight an israeli army observation post called in tank fire which killed the three gunmen . [SEP]
# pobj 20 14.0 118
#
# [CLS] during the fire fight an israeli army observation post called in tank fire which killed the three gunmen . [SEP]
# compound 15 13.0 118
#
# [CLS] during the fire fight an israeli army observation post called in tank fire which killed the three gunmen . [SEP]
# compound 16 14.0 118
#
# [CLS] during the fire fight an israeli army observation post called in tank fire which killed the three gunmen . [SEP]
# dobj 19 12.0 118
#
# [CLS] during the fire fight an israeli army observation post called in tank fire which killed the three gunmen . [SEP]
# compound 22 15.0 118
#
# [CLS] during the fire fight an israeli army observation post called in tank fire which killed the three gunmen . [SEP]
# pobj 11 7.0 118
#
# [CLS] during the fire fight an israeli army observation post called in tank fire which killed the three gunmen . [SEP]
# dobj 25 16.0 118
#
# [CLS] military tensions between india and pakistan have escalated to a level not seen since their 1971 war . [UNK] [SEP]
# nsubj 13 12.0 120
#
# [CLS] military tensions between india and pakistan have escalated to a level not seen since their 1971 war . [UNK] [SEP]
# pobj 18 13.0 120
#
# [CLS] military tensions between india and pakistan have escalated to a level not seen since their 1971 war . [UNK] [SEP]
# pobj 10 8.0 120
#
# [CLS] in total , more than 300 people have been flown from the island in two operations using chartered aircraft . [SEP]
# pobj 25 14.0 120
#
# [CLS] in total , more than 300 people have been flown from the island in two operations using chartered aircraft . [SEP]
# nsubjpass 23 17.0 120
#
# [CLS] in total , more than 300 people have been flown from the island in two operations using chartered aircraft . [SEP]
# pobj 30 18.0 120
#
# [CLS] in total , more than 300 people have been flown from the island in two operations using chartered aircraft . [SEP]
# pobj 24 14.0 120
#
# [CLS] in total , more than 300 people have been flown from the island in two operations using chartered aircraft . [SEP]
# dobj 24 18.0 120
#
# [CLS] meanwhile , there has been a mass airlift of detainees from christmas island to the pacific island of [UNK] . [SEP]
# attr 23 15.0 121
#
# [CLS] meanwhile , there has been a mass airlift of detainees from christmas island to the pacific island of [UNK] . [SEP]
# pobj 42 25.0 121
#
# [CLS] at [UNK] , four people were rescued after high voltage power lines fell across their car trapping them inside . [SEP]
# nsubjpass 15 14.0 123
#
# [CLS] at [UNK] , four people were rescued after high voltage power lines fell across their car trapping them inside . [SEP]
# compound 38 25.0 123
#
# [CLS] at [UNK] , four people were rescued after high voltage power lines fell across their car trapping them inside . [SEP]
# compound 26 20.0 123
#
# [CLS] at [UNK] , four people were rescued after high voltage power lines fell across their car trapping them inside . [SEP]
# nsubj 21 14.0 123
#
# [CLS] at [UNK] , four people were rescued after high voltage power lines fell across their car trapping them inside . [SEP]
# pobj 39 25.0 123
#
# [CLS] indian security forces have shot dead eight suspected militants in a night - long encounter in southern kashmir . [SEP]
# compound 12 8.0 125
#
# [CLS] indian security forces have shot dead eight suspected militants in a night - long encounter in southern kashmir . [SEP]
# nsubj 18 10.0 125
#
# [CLS] indian security forces have shot dead eight suspected militants in a night - long encounter in southern kashmir . [SEP]
# dobj 24 19.0 125
#
# [CLS] indian security forces have shot dead eight suspected militants in a night - long encounter in southern kashmir . [SEP]
# npadvmod 18 14.0 125
#
# [CLS] indian security forces have shot dead eight suspected militants in a night - long encounter in southern kashmir . [SEP]
# pobj 24 15.0 125
#
# [CLS] military tensions erupted between india and pakistan after the bloody december 13 raid on the indian parliament . [SEP]
# nsubj 13 10.0 125
#
# [CLS] military tensions erupted between india and pakistan after the bloody december 13 raid on the indian parliament . [SEP]
# pobj 20 16.0 125
#
# [CLS] military tensions erupted between india and pakistan after the bloody december 13 raid on the indian parliament . [SEP]
# pobj 40 20.0 125
#
# [CLS] the foreign affairs minister alexander [UNK] has refused to say for how long the claims process has been put on hold . [SEP]
# compound 48 26.0 130
#
# [CLS] the foreign affairs minister alexander [UNK] has refused to say for how long the claims process has been put on hold . [SEP]
# nsubjpass 22 15.0 130
#
# [CLS] the foreign affairs minister alexander [UNK] has refused to say for how long the claims process has been put on hold . [SEP]
# pobj 23 15.0 130
#
# [CLS] well we [UNK] very concerned and the body of [UNK] to the hospital - there are over 70 [UNK] that work in our service - [SEP]
# conj 24 18.0 131
#
# [CLS] well we [UNK] very concerned and the body of [UNK] to the hospital - there are over 70 [UNK] that work in our service - [SEP]
# pobj 23 13.0 131
#
# [CLS] well we [UNK] very concerned and the body of [UNK] to the hospital - there are over 70 [UNK] that work in our service - [SEP]
# pobj 25 15.0 131
#
# [CLS] the foreign minister , dr abdullah , appeared to be ending the confusion , saying an agreement was about to be signed . [SEP]
# dobj 36 22.0 131
#
# [CLS] the foreign minister , dr abdullah , appeared to be ending the confusion , saying an agreement was about to be signed . [SEP]
# nsubj 19 13.0 131
#
# [CLS] while few details are available at this stage , fire authorities says it has closed the hume highway in both directions . [SEP]
# nsubj 19 14.0 133
#
# [CLS] while few details are available at this stage , fire authorities says it has closed the hume highway in both directions . [SEP]
# pobj 36 22.0 133
#
# [CLS] while few details are available at this stage , fire authorities says it has closed the hume highway in both directions . [SEP]
# compound 37 26.0 133
#
# [CLS] while few details are available at this stage , fire authorities says it has closed the hume highway in both directions . [SEP]
# nsubj 28 16.0 133
#
# [CLS] while few details are available at this stage , fire authorities says it has closed the hume highway in both directions . [SEP]
# pobj 31 18.0 133
#
# [CLS] two hundred and thirty [UNK] left [UNK] last thursday , with just over 200 [UNK] across the finishing line at swan hill . [SEP]
# pobj 17 9.0 133
#
# [CLS] [UNK] , [UNK] by geoff [UNK] , got into trouble yesterday 46 miles from [UNK] point when it apparently struck an object . [SEP]
# pobj 17 13.0 133
#
# [CLS] [UNK] , [UNK] by geoff [UNK] , got into trouble yesterday 46 miles from [UNK] point when it apparently struck an object . [SEP]
# npadvmod 33 21.0 133
#
# [CLS] [UNK] , [UNK] by geoff [UNK] , got into trouble yesterday 46 miles from [UNK] point when it apparently struck an object . [SEP]
# npadvmod 23 18.0 133
#
# [CLS] [UNK] , [UNK] by geoff [UNK] , got into trouble yesterday 46 miles from [UNK] point when it apparently struck an object . [SEP]
# dobj 41 25.0 133
#
# [CLS] are very annoyed and angry at the inappropriate behaviour of these very senior people who should know better , " he said . [SEP]
# pobj 23 14.0 134
#
# [CLS] are very annoyed and angry at the inappropriate behaviour of these very senior people who should know better , " he said . [SEP]
# pobj 8 9.0 134
#
# [CLS] however he warned the " tension that has mounted on our eastern border in fact is creating obstacles and hurdles " . [UNK] [SEP]
# nsubj 20 16.0 134
#
# [CLS] however he warned the " tension that has mounted on our eastern border in fact is creating obstacles and hurdles " . [UNK] [SEP]
# pobj 26 18.0 134
#
# [CLS] however he warned the " tension that has mounted on our eastern border in fact is creating obstacles and hurdles " . [UNK] [SEP]
# pobj 30 18.0 134
#
# [CLS] however he warned the " tension that has mounted on our eastern border in fact is creating obstacles and hurdles " . [UNK] [SEP]
# dobj 27 22.0 134
#
# [CLS] however he warned the " tension that has mounted on our eastern border in fact is creating obstacles and hurdles " . [UNK] [SEP]
# conj 31 24.0 134
#
# [CLS] two palestinian gunmen also killed an israeli settler in [UNK] sinai on december 2 before being killed by the army . [UNK] [SEP]
# nsubj 16 13.0 134
#
# [CLS] two palestinian gunmen also killed an israeli settler in [UNK] sinai on december 2 before being killed by the army . [UNK] [SEP]
# dobj 31 21.0 134
#
# [CLS] two palestinian gunmen also killed an israeli settler in [UNK] sinai on december 2 before being killed by the army . [UNK] [SEP]
# pobj 30 23.0 134
#
# [CLS] only a protest will can now stop [UNK] 5 from [UNK] the overall handicap honours in the 57th sydney to hobart yacht race . [SEP]
# nsubj 38 22.0 134
#
# [CLS] only a protest will can now stop [UNK] 5 from [UNK] the overall handicap honours in the 57th sydney to hobart yacht race . [SEP]
# compound 46 31.0 134
#
# [CLS] only a protest will can now stop [UNK] 5 from [UNK] the overall handicap honours in the 57th sydney to hobart yacht race . [SEP]
# dobj 27 17.0 134
#
# [CLS] only a protest will can now stop [UNK] 5 from [UNK] the overall handicap honours in the 57th sydney to hobart yacht race . [SEP]
# compound 25 18.0 134
#
# [CLS] only a protest will can now stop [UNK] 5 from [UNK] the overall handicap honours in the 57th sydney to hobart yacht race . [SEP]
# pobj 15 11.0 134
#
# [CLS] south africa is considering playing left arm [UNK] nicky [UNK] in this week [UNK] third test against australia in sydney . [SEP]
# compound 30 20.0 134
#
# [CLS] south africa is considering playing left arm [UNK] nicky [UNK] in this week [UNK] third test against australia in sydney . [SEP]
# poss 33 20.0 134
#
# [CLS] south africa is considering playing left arm [UNK] nicky [UNK] in this week [UNK] third test against australia in sydney . [SEP]
# pobj 26 21.0 134
#
# [CLS] i just aim to keep improving in the new year , and if i do , i think i have a chance to beat anyone when i am playing well . [SEP]
# pobj 16 10.0 136
#
# [CLS] i just aim to keep improving in the new year , and if i do , i think i have a chance to beat anyone when i am playing well . [SEP]
# dobj 22 16.0 136
#
# [CLS] i just aim to keep improving in the new year , and if i do , i think i have a chance to beat anyone when i am playing well . [SEP]
# dobj 31 21.0 136
#
# [CLS] the israeli army has killed three palestinian militants who attacked one of its armoured vehicles in the northern gaza strip . [SEP]
# nsubj 24 19.0 138
#
# [CLS] the israeli army has killed three palestinian militants who attacked one of its armoured vehicles in the northern gaza strip . [SEP]
# dobj 20 16.0 138
#
# [CLS] the israeli army has killed three palestinian militants who attacked one of its armoured vehicles in the northern gaza strip . [SEP]
# pobj 20 15.0 138
#
# [CLS] the national road toll for the christmas - new year holiday period stands at 45 , eight fewer than for the same time last year . [SEP]
# compound 26 18.0 140
#
# [CLS] the national road toll for the christmas - new year holiday period stands at 45 , eight fewer than for the same time last year . [SEP]
# nsubj 34 23.0 140
#
# [CLS] the national road toll for the christmas - new year holiday period stands at 45 , eight fewer than for the same time last year . [SEP]
# compound 17 13.0 140
#
# [CLS] the national road toll for the christmas - new year holiday period stands at 45 , eight fewer than for the same time last year . [SEP]
# pobj 15 12.0 140
#
# [CLS] the national road toll for the christmas - new year holiday period stands at 45 , eight fewer than for the same time last year . [SEP]
# pobj 9 7.0 140
#
# [CLS] the national road toll for the christmas - new year holiday period stands at 45 , eight fewer than for the same time last year . [SEP]
# npadvmod 19 14.0 140
#
# [CLS] the [UNK] - old [UNK] , currently ranked eighth , recovered from a shaky start to [UNK] [UNK] [UNK] , 18 , who is ranked [UNK] . [SEP]
# pobj 14 8.0 140
#
# [CLS] hundreds of [UNK] are enjoying hard - earned new years eve celebrations following five days [UNK] in the murray river marathon . [SEP]
# nsubj 9 7.0 140
#
# [CLS] hundreds of [UNK] are enjoying hard - earned new years eve celebrations following five days [UNK] in the murray river marathon . [SEP]
# dobj 29 21.0 140
#
# [CLS] hundreds of [UNK] are enjoying hard - earned new years eve celebrations following five days [UNK] in the murray river marathon . [SEP]
# pobj 22 12.0 140
#
# [CLS] but a spokesman for the interior minister , [UNK] [UNK] , emerged soon after to say there was no agreement and nothing to sign . [SEP]
# nsubj 21 16.0 140
#
# [CLS] but a spokesman for the interior minister , [UNK] [UNK] , emerged soon after to say there was no agreement and nothing to sign . [SEP]
# attr 22 16.0 140
#
# [CLS] but a spokesman for the interior minister , [UNK] [UNK] , emerged soon after to say there was no agreement and nothing to sign . [SEP]
# conj 23 15.0 140
#
# [CLS] the falls have been quite isolated in those areas and generally the falls have been less than about five millimetres , " she said . [SEP]
# nsubjpass 12 7.0 143
#
# [CLS] the falls have been quite isolated in those areas and generally the falls have been less than about five millimetres , " she said . [SEP]
# pobj 19 14.0 143
#
# [CLS] the falls have been quite isolated in those areas and generally the falls have been less than about five millimetres , " she said . [SEP]
# nsubj 31 22.0 143
#
# [CLS] the falls have been quite isolated in those areas and generally the falls have been less than about five millimetres , " she said . [SEP]
# pobj 41 26.0 143
#
# [CLS] in north - western sydney only local residents are allowed to use [UNK] ferry road and upper color road under police escort . [UNK] [SEP]
# npadvmod 9 5.0 143
#
# [CLS] in north - western sydney only local residents are allowed to use [UNK] ferry road and upper color road under police escort . [UNK] [SEP]
# nsubjpass 12 9.0 143
#
# [CLS] in north - western sydney only local residents are allowed to use [UNK] ferry road and upper color road under police escort . [UNK] [SEP]
# compound 15 8.0 143
#
# [CLS] in north - western sydney only local residents are allowed to use [UNK] ferry road and upper color road under police escort . [UNK] [SEP]
# pobj 24 17.0 143
#
# [CLS] in some places really not significant at all , less than a [UNK] , so there has [UNK] been much relief as far as rain is concerned . [SEP]
# pobj 16 11.0 144
#
# [CLS] in some places really not significant at all , less than a [UNK] , so there has [UNK] been much relief as far as rain is concerned . [SEP]
# attr 28 17.0 144
#
# [CLS] in some places really not significant at all , less than a [UNK] , so there has [UNK] been much relief as far as rain is concerned . [SEP]
# nsubj 35 19.0 144
#
# [CLS] then the [UNK] - old [UNK] ( ranked 21st ) wore down a determined [UNK] clement , 24 , ( 18th ) to win 6 - 4 , 6 - 4 in 91 minutes . [SEP]
# npadvmod 25 17.0 144
#
# [CLS] then the [UNK] - old [UNK] ( ranked 21st ) wore down a determined [UNK] clement , 24 , ( 18th ) to win 6 - 4 , 6 - 4 in 91 minutes . [SEP]
# appos 29 21.0 144
#
# [CLS] then the [UNK] - old [UNK] ( ranked 21st ) wore down a determined [UNK] clement , 24 , ( 18th ) to win 6 - 4 , 6 - 4 in 91 minutes . [SEP]
# pobj 13 6.0 144
#
# [CLS] the second airlift today delivered 180 asylum seekers to [UNK] where they will await processing of their claims for temporary visas . [SEP]
# nsubj 40 24.0 145
#
# [CLS] the second airlift today delivered 180 asylum seekers to [UNK] where they will await processing of their claims for temporary visas . [SEP]
# npadvmod 31 15.0 145
#
# [CLS] the second airlift today delivered 180 asylum seekers to [UNK] where they will await processing of their claims for temporary visas . [SEP]
# compound 10 7.0 145
#
# [CLS] the second airlift today delivered 180 asylum seekers to [UNK] where they will await processing of their claims for temporary visas . [SEP]
# dobj 31 20.0 145
#
# [CLS] the second airlift today delivered 180 asylum seekers to [UNK] where they will await processing of their claims for temporary visas . [SEP]
# dobj 18 11.0 145
#
# [CLS] argentina [UNK] political and economic crisis has deepened with the resignation of its interim president who took office just a week ago . [SEP]
# pobj 17 14.0 150
#
# [CLS] argentina [UNK] political and economic crisis has deepened with the resignation of its interim president who took office just a week ago . [SEP]
# dobj 19 12.0 150
#
# [CLS] argentina [UNK] political and economic crisis has deepened with the resignation of its interim president who took office just a week ago . [SEP]
# npadvmod 23 13.0 150
#
# [CLS] president [UNK] said one of the goals of sunday [UNK] meeting was " to take stock of the internal situation , the domestic environment " . [SEP]
# pobj 19 15.0 150
#
# [CLS] president [UNK] said one of the goals of sunday [UNK] meeting was " to take stock of the internal situation , the domestic environment " . [SEP]
# pobj 37 28.0 150
#
# [CLS] president [UNK] said one of the goals of sunday [UNK] meeting was " to take stock of the internal situation , the domestic environment " . [SEP]
# dobj 57 34.0 150
#
# [CLS] president [UNK] said one of the goals of sunday [UNK] meeting was " to take stock of the internal situation , the domestic environment " . [SEP]
# pobj 10 7.0 150
#
# [CLS] president [UNK] said one of the goals of sunday [UNK] meeting was " to take stock of the internal situation , the domestic environment " . [SEP]
# dobj 24 19.0 150
#
# [CLS] president [UNK] also said he welcomed the intervention of the international community in trying to [UNK] the potentially explosive crisis . [SEP]
# dobj 24 16.0 151
#
# [CLS] president [UNK] also said he welcomed the intervention of the international community in trying to [UNK] the potentially explosive crisis . [SEP]
# pobj 18 12.0 151
#
# [CLS] president [UNK] also said he welcomed the intervention of the international community in trying to [UNK] the potentially explosive crisis . [SEP]
# dobj 30 19.0 151
#
# [CLS] in fact , they [UNK] probably hampered the efforts of the firefighters more because of the wind [UNK] that are associated with those [UNK] . [SEP]
# pobj 32 17.0 152
#
# [CLS] in fact , they [UNK] probably hampered the efforts of the firefighters more because of the wind [UNK] that are associated with those [UNK] . [SEP]
# dobj 17 11.0 152
#
# [CLS] in fact , they [UNK] probably hampered the efforts of the firefighters more because of the wind [UNK] that are associated with those [UNK] . [SEP]
# pobj 30 17.0 152
#
# [CLS] in fact , they [UNK] probably hampered the efforts of the firefighters more because of the wind [UNK] that are associated with those [UNK] . [SEP]
# compound 46 27.0 152
#
# [CLS] talks between afghan and british officials in kabul have ended without final agreement on the deployment of a international security force . [SEP]
# nsubj 13 7.0 152
#
# [CLS] talks between afghan and british officials in kabul have ended without final agreement on the deployment of a international security force . [SEP]
# pobj 13 10.0 152
#
# [CLS] talks between afghan and british officials in kabul have ended without final agreement on the deployment of a international security force . [SEP]
# pobj 14 8.0 152
#
# [CLS] talks between afghan and british officials in kabul have ended without final agreement on the deployment of a international security force . [SEP]
# pobj 21 13.0 152
#
# [CLS] talks between afghan and british officials in kabul have ended without final agreement on the deployment of a international security force . [SEP]
# compound 13 9.0 152
#
# [CLS] talks between afghan and british officials in kabul have ended without final agreement on the deployment of a international security force . [SEP]
# pobj 15 11.0 152
#
# [CLS] but the bureau of [UNK] [UNK] claire richards says the rain has done little to ease any of the hundred fires still burning across the state . [SEP]
# nsubj 47 32.0 153
#
# [CLS] but the bureau of [UNK] [UNK] claire richards says the rain has done little to ease any of the hundred fires still burning across the state . [SEP]
# pobj 16 15.0 153
#
# [CLS] but the bureau of [UNK] [UNK] claire richards says the rain has done little to ease any of the hundred fires still burning across the state . [SEP]
# pobj 29 14.0 153
#
# [CLS] despite the caution , the rural fire service says most of the state [UNK] fires that threaten property are burning within containment lines . [SEP]
# pobj 24 17.0 153
#
# [CLS] despite the caution , the rural fire service says most of the state [UNK] fires that threaten property are burning within containment lines . [SEP]
# poss 40 21.0 153
#
# [CLS] despite the caution , the rural fire service says most of the state [UNK] fires that threaten property are burning within containment lines . [SEP]
# pobj 8 7.0 153
#
# [CLS] despite the caution , the rural fire service says most of the state [UNK] fires that threaten property are burning within containment lines . [SEP]
# dobj 39 26.0 153
#
# [CLS] despite the caution , the rural fire service says most of the state [UNK] fires that threaten property are burning within containment lines . [SEP]
# compound 21 16.0 153
#
# [CLS] despite the caution , the rural fire service says most of the state [UNK] fires that threaten property are burning within containment lines . [SEP]
# pobj 28 16.0 153
#
# [CLS] meanwhile , a south australian yacht in the sydney to hobart has been towed to st helens on tasmania [UNK] east coast after losing its rudder . [SEP]
# nsubjpass 21 17.0 155
#
# [CLS] meanwhile , a south australian yacht in the sydney to hobart has been towed to st helens on tasmania [UNK] east coast after losing its rudder . [SEP]
# pobj 25 16.0 155
#
# [CLS] meanwhile , a south australian yacht in the sydney to hobart has been towed to st helens on tasmania [UNK] east coast after losing its rudder . [SEP]
# dobj 28 19.0 155
#
# [CLS] however , that [UNK] not to say that these fires wo [UNK] pose a threat given the weather conditions that are coming up over the next few days . [SEP]
# nsubj 36 20.0 156
#
# [CLS] however , that [UNK] not to say that these fires wo [UNK] pose a threat given the weather conditions that are coming up over the next few days . [SEP]
# dobj 21 17.0 156
#
# [CLS] however , that [UNK] not to say that these fires wo [UNK] pose a threat given the weather conditions that are coming up over the next few days . [SEP]
# compound 9 6.0 156
#
# [CLS] however , that [UNK] not to say that these fires wo [UNK] pose a threat given the weather conditions that are coming up over the next few days . [SEP]
# pobj 12 10.0 156
#
# [CLS] however , that [UNK] not to say that these fires wo [UNK] pose a threat given the weather conditions that are coming up over the next few days . [SEP]
# pobj 25 14.0 156
#
# [CLS] president general [UNK] [UNK] says pakistan wants to [UNK] the brewing crisis with india , but was prepared to respond vigorously to any attack . [SEP]
# compound 31 20.0 157
#
# [CLS] president general [UNK] [UNK] says pakistan wants to [UNK] the brewing crisis with india , but was prepared to respond vigorously to any attack . [SEP]
# dobj 26 16.0 157
#
# [CLS] president general [UNK] [UNK] says pakistan wants to [UNK] the brewing crisis with india , but was prepared to respond vigorously to any attack . [SEP]
# pobj 14 11.0 157
#
# [CLS] in the second set , [UNK] broke her opponent in the opening game and completed victory with relative ease despite [UNK] [UNK] [UNK] efforts . [UNK] [SEP]
# pobj 32 20.0 159
#
# [CLS] in the second set , [UNK] broke her opponent in the opening game and completed victory with relative ease despite [UNK] [UNK] [UNK] efforts . [UNK] [SEP]
# dobj 28 20.0 159
#
# dobj 19 13.0 235
#
# [CLS] fresh elections are not scheduled until march leaving whoever assumes the presidency with the [UNK] task of [UNK] argentina [UNK] worst crisis in 12 years , but this time , isolated by international lending agencies . [UNK] [SEP]
# pobj 22 18.0 235
#
# [CLS] fresh elections are not scheduled until march leaving whoever assumes the presidency with the [UNK] task of [UNK] argentina [UNK] worst crisis in 12 years , but this time , isolated by international lending agencies . [UNK] [SEP]
# dobj 41 26.0 235
#
# [CLS] fresh elections are not scheduled until march leaving whoever assumes the presidency with the [UNK] task of [UNK] argentina [UNK] worst crisis in 12 years , but this time , isolated by international lending agencies . [UNK] [SEP]
# pobj 14 11.0 235
#
# [CLS] fresh elections are not scheduled until march leaving whoever assumes the presidency with the [UNK] task of [UNK] argentina [UNK] worst crisis in 12 years , but this time , isolated by international lending agencies . [UNK] [SEP]
# conj 17 11.0 235
#
# [CLS] fresh elections are not scheduled until march leaving whoever assumes the presidency with the [UNK] task of [UNK] argentina [UNK] worst crisis in 12 years , but this time , isolated by international lending agencies . [UNK] [SEP]
# compound 53 24.0 235
#
# [CLS] fresh elections are not scheduled until march leaving whoever assumes the presidency with the [UNK] task of [UNK] argentina [UNK] worst crisis in 12 years , but this time , isolated by international lending agencies . [UNK] [SEP]
# pobj 29 19.0 235
#
# [CLS] the new south wales rural fire service says the weather conditions which caused the fire to burn in a finger formation have now eased and about 60 fire units in and around hill top are optimistic of defending all properties . [SEP]
# compound 10 7.0 237
#
# [CLS] the new south wales rural fire service says the weather conditions which caused the fire to burn in a finger formation have now eased and about 60 fire units in and around hill top are optimistic of defending all properties . [SEP]
# nsubj 19 15.0 237
#
# [CLS] the new south wales rural fire service says the weather conditions which caused the fire to burn in a finger formation have now eased and about 60 fire units in and around hill top are optimistic of defending all properties . [SEP]
# nsubj 10 7.0 237
#
# [CLS] the new south wales rural fire service says the weather conditions which caused the fire to burn in a finger formation have now eased and about 60 fire units in and around hill top are optimistic of defending all properties . [SEP]
# compound 31 19.0 237
#
# [CLS] the new south wales rural fire service says the weather conditions which caused the fire to burn in a finger formation have now eased and about 60 fire units in and around hill top are optimistic of defending all properties . [SEP]
# pobj 52 28.0 237
#
# [CLS] the new south wales rural fire service says the weather conditions which caused the fire to burn in a finger formation have now eased and about 60 fire units in and around hill top are optimistic of defending all properties . [SEP]
# compound 17 13.0 237
#
# [CLS] the new south wales rural fire service says the weather conditions which caused the fire to burn in a finger formation have now eased and about 60 fire units in and around hill top are optimistic of defending all properties . [SEP]
# nsubj 20 16.0 237
#
# [CLS] the new south wales rural fire service says the weather conditions which caused the fire to burn in a finger formation have now eased and about 60 fire units in and around hill top are optimistic of defending all properties . [SEP]
# dobj 20 14.0 237
#
# [CLS] at about [UNK] [UNK] , a marked deterioration in the weather as a storm cell moved east across the blue mountains forced authorities to make a decision to evacuate people from homes in outlying streets at hill top in the new south wales southern highlands . [SEP]
# nsubj 48 28.0 269
#
# [CLS] at about [UNK] [UNK] , a marked deterioration in the weather as a storm cell moved east across the blue mountains forced authorities to make a decision to evacuate people from homes in outlying streets at hill top in the new south wales southern highlands . [SEP]
# pobj 14 8.0 269
#
# [CLS] at about [UNK] [UNK] , a marked deterioration in the weather as a storm cell moved east across the blue mountains forced authorities to make a decision to evacuate people from homes in outlying streets at hill top in the new south wales southern highlands . [SEP]
# compound 31 18.0 269
#
# [CLS] at about [UNK] [UNK] , a marked deterioration in the weather as a storm cell moved east across the blue mountains forced authorities to make a decision to evacuate people from homes in outlying streets at hill top in the new south wales southern highlands . [SEP]
# pobj 49 27.0 269
#
# [CLS] at about [UNK] [UNK] , a marked deterioration in the weather as a storm cell moved east across the blue mountains forced authorities to make a decision to evacuate people from homes in outlying streets at hill top in the new south wales southern highlands . [SEP]
# dobj 21 15.0 269
#
# [CLS] at about [UNK] [UNK] , a marked deterioration in the weather as a storm cell moved east across the blue mountains forced authorities to make a decision to evacuate people from homes in outlying streets at hill top in the new south wales southern highlands . [SEP]
# dobj 16 12.0 269
#
# [CLS] at about [UNK] [UNK] , a marked deterioration in the weather as a storm cell moved east across the blue mountains forced authorities to make a decision to evacuate people from homes in outlying streets at hill top in the new south wales southern highlands . [SEP]
# dobj 19 15.0 269
#
# [CLS] at about [UNK] [UNK] , a marked deterioration in the weather as a storm cell moved east across the blue mountains forced authorities to make a decision to evacuate people from homes in outlying streets at hill top in the new south wales southern highlands . [SEP]
# pobj 20 13.0 269
#
# [CLS] at about [UNK] [UNK] , a marked deterioration in the weather as a storm cell moved east across the blue mountains forced authorities to make a decision to evacuate people from homes in outlying streets at hill top in the new south wales southern highlands . [SEP]
# pobj 24 17.0 269

# %% [markdown]
# # Count tokens

# %%
def get_count():
    count_pos, count_dep, count_mixed = {}, {}, {}
    count_pos_layer, count_dep_layer, count_mixed_layer = {}, {}, {}
    for token, pos, dep, gates, line in gen_token():
        sum_gates = [sum(gates)]
        sum_gates_layer = [np.array(gates).reshape(12, 12).sum(axis=1)]

        if pos not in count_pos:
            count_pos[pos] = []
            count_pos_layer[pos] = []
        if dep not in count_dep:
            count_dep[dep] = []
            count_dep_layer[dep] = []
        if (pos, dep) not in count_mixed:
            count_mixed[(pos, dep)] = []
            count_mixed_layer[(pos, dep)] = []

        count_dep[dep] += sum_gates
        count_dep_layer[dep] += sum_gates_layer

        count_pos[pos] += sum_gates
        count_pos_layer[pos] += sum_gates_layer

        count_mixed[(pos, dep)] += sum_gates
        count_mixed_layer[(pos, dep)] += sum_gates_layer

    return (count_pos, count_dep, count_mixed,
            count_pos_layer, count_dep_layer, count_mixed_layer)

count_pos, count_dep, count_mixed, count_pos_layer, count_dep_layer, count_mixed_layer = get_count()

# %%
def explore_sub(fct, key):
    count = {}
    for token, pos, dep, gates, line in gen_token():
        if fct(pos, dep) == key:
            if fct(dep, pos) not in count:
                count[fct(dep, pos)] = []
            count[fct(dep, pos)] += [sum(gates)]
    return count

# %%
dep_ann = {
    "acl": "clausal modifier of noun (adjectival clause)",
"acomp":"adjectival complement",
"advcl":"adverbial clause modifier",
"advmod":"adverbial modifier",
"agent":"agent",
"amod":"adjectival modifier",
"appos":"appositional modifier",
"attr":"attribute",
"aux":"auxiliary",
"auxpass":"auxiliary (passive)",
"case":"case marking",
"cc":"coordinating conjunction",
"ccomp":"clausal complement",
"compound":"compound",
"conj":"conjunct",
"cop":"copula",
"csubj":"clausal subject",
"csubjpass":"clausal subject (passive)",
"dative":"dative",
"dep":"unclassified dependent",
"det":"determiner",
"dobj":"direct object",
"expl":"expletive",
"intj":"interjection",
"mark":"marker",
"meta":"meta modifier",
"neg":"negation modifier",
"nn":"noun compound modifier",
"nounmod":"modifier of nominal",
"npmod":"noun phrase as adverbial modifier",
"nsubj":"nominal subject",
"nsubjpass":"nominal subject (passive)",
"nummod":"numeric modifier",
"oprd":"object predicate",
"obj":"object",
"obl":"oblique nominal",
"parataxis":"parataxis",
"pcomp":"complement of preposition",
"pobj":"object of preposition",
"poss":"possession modifier",
"preconj":"pre-correlative conjunction",
"prep":"prepositional modifier",
"prt":"particle",
"punct":"punctuation",
"quantmod":"modifier of quantifier",
"relcl":"relative clause modifier",
"root":"root",
"xcomp":"open clausal complement",
}

# %% [markdown]
# # tableau: moyenne, écart standard

# %%
sort = lambda z : sorted(z, key=lambda x: -np.mean(z[x]))

print ("{:<10}{:<10}{:<10}{}".format("POS", "Freq", "Mean", "Std Dev\n"))
for k in sort(count_pos):
    if len(count_pos[k]) > 5:
        print ("{:<10}{:<10}{:<10}{}".format(k,
                                             len(count_pos[k]),
                                             round(np.mean(count_pos[k])),
                                             round(np.std(count_pos[k]))))
# Out:
# POS       Freq      Mean      Std Dev
#
# PROPN     319       24.0      12.0
# NOUN      624       23.0      10.0
# ADJ       228       23.0      11.0
# NUM       95        22.0      11.0
# ADV       137       20.0      12.0
# VERB      551       18.0      10.0
# PRON      83        12.0      8.0
# CCONJ     83        12.0      7.0
# ADP       434       12.0      7.0
# DET       372       9.0       6.0
# PART      72        9.0       12.0
# SYM       10        7.0       2.0
# PUNCT     367       7.0       6.0

# %%
print ("{:<15}{:<10}{:<10}{}".format("POS", "Freq", "Mean", "Std Dev\n"))

for k in sort(count_mixed):
    if len(count_mixed[k]) > 5:
        print ("{:<15}{:<10}{:<10}{}".format("-".join(k),
                                             len(count_mixed[k]),
                                             round(np.mean(count_mixed[k])),
                                             round(np.std(count_mixed[k]))))
# Out:
# POS            Freq      Mean      Std Dev
#
# NOUN-poss      6         36.0      3.0
# PROPN-poss     12        32.0      12.0
# PROPN-dobj     11        29.0      13.0
# PART-prt       11        29.0      11.0
# PROPN-pobj     90        27.0      11.0
# PRON-dobj      6         26.0      10.0
# ADJ-acomp      19        25.0      11.0
# VERB-xcomp     42        25.0      10.0
# NOUN-dobj      118       25.0      10.0
# VERB-amod      12        24.0      9.0
# NOUN-nsubj     91        24.0      10.0
# ADJ-advmod     6         24.0      10.0
# NOUN-pobj      235       24.0      10.0
# NUM-nummod     66        23.0      12.0
# VERB-pcomp     9         23.0      10.0
# ADJ-amod       185       23.0      11.0
# NOUN-compound  80        23.0      10.0
# PROPN-compound 131       23.0      14.0
# NOUN-npadvmod  26        23.0      9.0
# PROPN-nsubj    36        23.0      10.0
# NOUN-attr      11        23.0      11.0
# VERB-conj      26        22.0      10.0
# VERB-acl       25        22.0      10.0
# PROPN-conj     19        22.0      7.0
# VERB-prep      7         22.0      6.0
# ADP-quantmod   10        22.0      10.0
# VERB-relcl     31        21.0      10.0
# ADV-advmod     110       21.0      12.0
# VERB-advcl     40        21.0      10.0
# NUM-prep       8         21.0      5.0
# NOUN-conj      20        20.0      5.0
# ADJ-conj       8         20.0      6.0
# PROPN-nmod     8         19.0      7.0
# VERB-ccomp     65        19.0      10.0
# VERB-ROOT      145       18.0      9.0
# NOUN-nsubjpass 21        18.0      8.0
# DET-poss       32        15.0      6.0
# ADP-mark       31        14.0      8.0
# VERB-auxpass   45        14.0      7.0
# DET-nsubj      17        13.0      6.0
# CCONJ-cc       82        12.0      7.0
# ADV-neg        14        12.0      5.0
# VERB-aux       98        11.0      5.0
# ADP-prep       369       11.0      6.0
# PRON-nsubj     71        11.0      6.0
# ADP-agent      12        11.0      4.0
# PUNCT-ROOT     34        11.0      1.0
# ADV-expl       7         9.0       6.0
# DET-det        310       8.0       5.0
# SYM-punct      8         7.0       3.0
# PUNCT-punct    333       6.0       6.0
# PART-aux       60        5.0       6.0

# %%
print ("{:<15}{:<15}{:<10}{:<10}{}".format("POS", "DEP", "Freq", "Mean", "Std Dev\n"))

for k in sort(count_pos):
    if len(count_pos[k]) > 5:
        print ("\n{:<15}".format(k))
        count = explore_sub(lambda pos, dep: pos, k)
        for n in sort(count):
            if len(count[n]) > 5:
                print ("{:<15}{:<15}{:<10}{:<10}{}".format("",
                                                           n,
                                                           len(count[n]),
                                                           round(np.mean(count[n])),
                                                           round(np.std(count[n]))))
# Out:
# POS            DEP            Freq      Mean      Std Dev
#
#
# PROPN
#                poss           12        32.0      12.0
#                dobj           11        29.0      13.0
#                pobj           90        27.0      11.0
#                compound       131       23.0      14.0
#                nsubj          36        23.0      10.0
#                conj           19        22.0      7.0
#                nmod           8         19.0      7.0
#
# NOUN
#                poss           6         36.0      3.0
#                dobj           118       25.0      10.0
#                nsubj          91        24.0      10.0
#                pobj           235       24.0      10.0
#                compound       80        23.0      10.0
#                npadvmod       26        23.0      9.0
#                attr           11        23.0      11.0
#                conj           20        20.0      5.0
#                nsubjpass      21        18.0      8.0
#
# ADJ
#                acomp          19        25.0      11.0
#                advmod         6         24.0      10.0
#                amod           185       23.0      11.0
#                conj           8         20.0      6.0
#
# NUM
#                nummod         66        23.0      12.0
#                prep           8         21.0      5.0
#
# ADV
#                advmod         110       21.0      12.0
#                neg            14        12.0      5.0
#                expl           7         9.0       6.0
#
# VERB
#                xcomp          42        25.0      10.0
#                amod           12        24.0      9.0
#                pcomp          9         23.0      10.0
#                conj           26        22.0      10.0
#                acl            25        22.0      10.0
#                prep           7         22.0      6.0
#                relcl          31        21.0      10.0
#                advcl          40        21.0      10.0
#                ccomp          65        19.0      10.0
#                ROOT           145       18.0      9.0
#                auxpass        45        14.0      7.0
#                aux            98        11.0      5.0
#
# PRON
#                dobj           6         26.0      10.0
#                nsubj          71        11.0      6.0
#
# CCONJ
#                cc             82        12.0      7.0
#
# ADP
#                quantmod       10        22.0      10.0
#                mark           31        14.0      8.0
#                prep           369       11.0      6.0
#                agent          12        11.0      4.0
#
# DET
#                poss           32        15.0      6.0
#                nsubj          17        13.0      6.0
#                det            310       8.0       5.0
#
# PART
#                prt            11        29.0      11.0
#                aux            60        5.0       6.0
#
# SYM
#                punct          8         7.0       3.0
#
# PUNCT
#                ROOT           34        11.0      1.0
#                punct          333       6.0       6.0

# %% [markdown]
# # Layer par layer

# %%
def sort_layer(n_layer):
    sort = lambda z : sorted(z, key=lambda x: -np.mean(np.array(z[x])[:,n_layer]))

    print ("{:<10}{:<10}{:<10}{}".format("POS", "Freq", "Mean", "Std Dev\n"))
    for k in sort(count_pos_layer):
        layer_gates = np.array(count_pos_layer[k])[:,n_layer]
        if len(layer_gates) > 5:
            print ("{:<10}{:<10}{:<10}{}".format(k,
                                             len(layer_gates),
                                             round(layer_gates.mean(), 4),
                                             round(np.std(layer_gates), 4)))

# %%
for i in range(12):
    print ("layer", i+1)
    sort_layer(i)
    print ()

# %%
norm = lambda x: x / np.sum(x)
slice_mean = lambda x, n: x.reshape(int(12/n), n).mean(axis=1)
layer_mean = lambda x: np.array(x).mean(axis=0)

# %%
plt.figure(figsize=(20,20))
for k in count_pos_layer:
    if len(count_pos_layer[k]) > 100:
        plt.plot((layer_mean(count_pos_layer[k])), label=k)
plt.legend()

# %%
coeff = [ (k, np.corrcoef(np.arange(12), layer_mean(count_pos_layer[k]))[0][1]) for k in count_pos_layer ]

order_k = []
coeff = sorted(coeff, key=lambda x: -x[1])
for k, val in coeff:
    if len(count_pos_layer[k]) > 100:
        print ("{:<10}{}".format(k, val))
        order_k += [k]
# Out:
# PROPN     0.3665183668299445
# NOUN      0.30524914642641565
# ADJ       0.23507703853771145
# ADV       0.16619585497253872
# VERB      0.03731856888785097
# DET       -0.2681378870497394
# ADP       -0.27357806143658114
# PUNCT     -0.7011768490899075

# %%
plt.figure(figsize=(20,20))
for k in count_pos_layer:
    if len(count_pos_layer[k]) > 100:
        plt.plot(norm(slice_mean(layer_mean(count_pos_layer[k]), 6)), label=k)
plt.legend()

# %%
merge = [["PROPN", "NOUN", "ADJ"], ["ADV", "VERB"], ["DET", "ADP"], ["PUNCT"] ]

# %%
fig, ax = plt.subplots(figsize=(10, 10))
index = np.arange(12)
bar_width = 1/6
opacity = 0.8

for i, k in enumerate(merge):

    val = norm(np.array([ layer_mean(count_pos_layer[e]) for e in k ]).sum(axis=0))
    plt.bar(index + bar_width * i, val, bar_width, alpha=opacity, label=", ".join(k))


plt.xlabel('Layers')
plt.ylabel('Mean number of gates')
plt.title('Normalized gates mean Layer/POS')

plt.xticks(index + bar_width, [ str(i+1) for i in np.arange(12)])
plt.legend()

plt.tight_layout()
plt.show()
